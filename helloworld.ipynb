# %% [markdown]
# <a href="https://colab.research.google.com/github/fjpc0727-gif/trabajo-de-algebra/blob/main/helloworld.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("hello world Francis Paulino")
# Out:
# hello world Francis Paulino
